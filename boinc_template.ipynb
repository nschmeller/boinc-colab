# %% [markdown]
# <a href="https://colab.research.google.com/github/nschmeller/boinc-colab/blob/main/boinc_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install boinc
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   aspell aspell-en boinc-client boinc-manager dictionaries-common
#   emacsen-common enchant gstreamer1.0-gl gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-pulseaudio gstreamer1.0-x
#   hunspell-en-us libaa1 libaspell15 libboinc7 libbrotli1 libcap2-bin
#   libcdparanoia0 libdv4 libenchant1c2a libgpm2 libgraphene-1.0-0
#   libgstreamer-gl1.0-0 libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libgstreamer1.0-0 libhunspell-1.6-0
#   libhyphen0 libjavascriptcoregtk-4.0-18 libnotify4 liborc-0.4-0 libpam-cap
#   libsecret-1-0 libsecret-common libshout3 libtag1v5 libtag1v5-vanilla
#   libtext-iconv-perl libv4l-0 libv4lconvert0 libvisual-0.4-0
#   libwebkit2gtk-4.0-37 libwoff1 libwxbase3.0-0v5 libwxgtk-webview3.0-gtk3-0v5
#   libwxgtk3.0-gtk3-0v5 notification-daemon
# Suggested packages:
# ...

# %%
# !tmux new-session -d -s boinc

# %%
# !tmux send-keys 'boinc' C-m

# %%
# !boinccmd --lookup_account URL USERNAME PASSWORD

# eg URL = http://einstein.phys.uwm.edu/
# with your einstein@home username and password
# this cell prints your ACCOUNT_ID

# %%
# this cell downloads tasks and starts running them!
# copy over the URL you used in the last cell and ACCOUNT_ID produced by last cell

# !boinccmd --project_attach URL ACCOUNT_ID

# %%
# get status of tasks with --get_state or --get_tasks

# !boinccmd --get_tasks
# Out:
# ======== Tasks ========
# 1) -----------
#    name: h1_0191.95_O2C02Cl5In0__O2MD1S1a_Spotlight_192.20Hz_2075_1
#    WU name: h1_0191.95_O2C02Cl5In0__O2MD1S1a_Spotlight_192.20Hz_2075
#    project URL: http://einstein.phys.uwm.edu/
#    received: Wed Dec 16 16:49:37 2020
#    report deadline: Wed Dec 30 16:05:30 2020
#    ready to report: no
#    state: downloaded
#    scheduler state: scheduled
#    active_task_state: EXECUTING
#    app version num: 208
#    resources: 1 CPU
#    CPU time at last checkpoint: 0.000000
#    current CPU time: 32.389020
#    estimated CPU time remaining: 43156.016137
#    fraction done: 0.000000
#    swap size: 235 MB
#    working set size: 191 MB
#    suspended via GUI: no
# 2) -----------
#    name: h1_0191.95_O2C02Cl5In0__O2MD1S1a_Spotlight_192.20Hz_2073_0
#    WU name: h1_0191.95_O2C02Cl5In0__O2MD1S1a_Spotlight_192.20Hz_2073
#    project URL: http://einstein.phys.uwm.edu/
#    received: Wed Dec 16 16:49:37 2020
# ...
